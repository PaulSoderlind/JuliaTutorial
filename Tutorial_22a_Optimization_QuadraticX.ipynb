# %% [markdown]
# # Optimization
#
# of linear-quadratic problems, using the [OSQP.jl](https://github.com/osqp/OSQP.jl) package.
#
# See Ch23_5a_Optimization_Quadratic.ipynb in the ModernFinanceTheory repository.
